# %% [markdown]
# Name: Haoran Zhu <br>
# UNI: hz2712

# %%
# %load_ext sql
# %sql mysql+pymysql://root:Zhr990512@@localhost/HW4GoT

# %% [markdown]
# GoT

# %%
# %sql show tables from HW4GoT
# Out:
#  * mysql+pymysql://root:***@localhost/HW4GoT
# 8 rows affected.
# [('character_relationships',),
#  ('characters',),
#  ('characters_actors',),
#  ('episodes',),
#  ('groups',),
#  ('locations',),
#  ('scenes',),
#  ('scenes_characters',)]

# %%
# %sql select * from HW4GoT.characters limit 10
# Out:
#  * mysql+pymysql://root:***@localhost/HW4GoT
# 10 rows affected.
# [(0, 'Addam Marbrand', '/character/ch0305333/', 'B.J. Hogg', '/name/nm0389698/', 'CH_0', None, None, None, None, None),
#  (1, 'Aegon Targaryen', None, None, None, 'CH_1', 1, None, None, None, None),
#  (2, 'Aeron Greyjoy', '/character/ch0540081/', 'Michael Feast', '/name/nm0269923/', 'CH_2', None, 'https://images-na.ssl-images-amazon.com/images/M/MV5BNzI5MDg0ZDAtN2Y2ZC00MzU1LTgyYjQtNTBjYjEzODczZDVhXkEyXkFqcGdeQXVyNTg0Nzg4NTE@._V1._SX100_SY140_.jpg', 'https://images-na.ssl-images-amazon.com/images/M/MV5BNzI5MDg0ZDAtN2Y2ZC00MzU1LTgyYjQtNTBjYjEzODczZDVhXkEyXkFqcGdeQXVyNTg0Nzg4NTE@._V1_.jpg', 'Damphair', None),
# ...

# %%
# %sql select * from HW4GoT.characters_actors limit 10
# Out:
#  * mysql+pymysql://root:***@localhost/HW4GoT
# 10 rows affected.
# [(0, 'CH_0', 'B.J. Hogg', '/name/nm0389698/', None),
#  (1, 'CH_2', 'Michael Feast', '/name/nm0269923/', None),
#  (2, 'CH_3', 'David Rintoul', '/name/nm0727778/', None),
#  (3, 'CH_4', 'Chuku Modu', '/name/nm6729880/', None),
#  (4, 'CH_5', 'Owen Teale', '/name/nm0853583/', None),
#  (5, 'CH_6', 'Karl Davies', '/name/nm0203801/', None),
#  (6, 'CH_7', 'Megan Parkinson', '/name/nm8257864/', None),
#  (7, 'CH_8', 'Fintan McKeown', '/name/nm0571654/', None),
#  (8, 'CH_9', 'Philip McGinley', '/name/nm1528121/', None),
#  (9, 'CH_10', 'Jim Broadbent', '/name/nm0000980/', None)]

# %%
# %sql select * from HW4GoT.character_relationships limit 10
# Out:
#  * mysql+pymysql://root:***@localhost/HW4GoT
# 10 rows affected.
# [(0, 'CH_1', 'Aegon Targaryen', 'parents', 'Elia Martell'),
#  (1, 'CH_1', 'Aegon Targaryen', 'parents', 'Rhaegar Targaryen'),
#  (2, 'CH_1', 'Aegon Targaryen', 'siblings', 'Rhaenys Targaryen'),
#  (3, 'CH_1', 'Aegon Targaryen', 'siblings', 'Jon Snow'),
#  (4, 'CH_1', 'Aegon Targaryen', 'killedBy', 'Gregor Clegane'),
#  (5, 'CH_2', 'Aeron Greyjoy', 'siblings', 'Balon Greyjoy'),
#  (6, 'CH_2', 'Aeron Greyjoy', 'siblings', 'Euron Greyjoy'),
#  (7, 'CH_3', 'Aerys II Targaryen', 'killed', 'Brandon Stark'),
#  (8, 'CH_3', 'Aerys II Targaryen', 'killed', 'Rickard Stark'),
#  (9, 'CH_3', 'Aerys II Targaryen', 'servedBy', 'Arthur Dayne')]

# %%
# %sql select * from HW4GoT.episodes limit 10
# Out:
#  * mysql+pymysql://root:***@localhost/HW4GoT
# 10 rows affected.
# [(0, 1, 1, 'Winter Is Coming', '/title/tt1480055/', '2011-04-17', "Jon Arryn, the Hand of the King, is dead. King Robert Baratheon plans to ask his oldest friend, Eddard Stark, to take Jon's place. Across the sea, Viserys Targaryen plans to wed his sister to a nomadic warlord in exchange for an army."),
#  (1, 1, 2, 'The Kingsroad', '/title/tt1668746/', '2011-04-24', "While Bran recovers from his fall, Ned takes only his daughters to King's Landing. Jon Snow goes with his uncle Benjen to The Wall. Tyrion joins them."),
#  (2, 1, 3, 'Lord Snow', '/title/tt1829962/', '2011-05-01', "Lord Stark and his daughters arrive at King's Landing to discover the intrigues of the king's realm."),
#  (3, 1, 4, 'Cripples, Bastards, and Broken Things', '/title/tt1829963/', '2011-05-08', "Eddard investigates Jon Arryn's murder. Jon befriends Samwell Tarly, a coward who has come to join the Night's Watch."),
# ...

# %%
# %sql select * from HW4GoT.groups limit 10
# Out:
#  * mysql+pymysql://root:***@localhost/HW4GoT
# 10 rows affected.
# [(0, 'Stark', None),
#  (1, 'Stark', 'Arya Stark'),
#  (2, 'Stark', 'Benjen Stark'),
#  (3, 'Stark', 'Bran Stark'),
#  (4, 'Stark', 'Catelyn Stark'),
#  (5, 'Stark', 'Eddard Stark'),
#  (6, 'Stark', 'Ghost'),
#  (7, 'Stark', 'Grey Wind'),
#  (8, 'Stark', 'Jon Snow'),
#  (9, 'Stark', 'Lady')]

# %%
# %sql select * from HW4GoT.locations limit 10
# Out:
#  * mysql+pymysql://root:***@localhost/HW4GoT
# 10 rows affected.
# [(0, 'North of the Wall', None),
#  (1, 'North of the Wall', 'The Lands of Always Winter'),
#  (2, 'North of the Wall', 'Cave Outside Wildling Camp'),
#  (3, 'North of the Wall', 'Wildling Camp'),
#  (4, 'North of the Wall', 'Frostfang Mountains'),
#  (5, 'North of the Wall', 'The Three-Eyed Raven'),
#  (6, 'North of the Wall', 'Outside the Three-Eyed Raven'),
#  (7, 'North of the Wall', 'Fist of the First Men'),
#  (8, 'North of the Wall', 'Wildlings March South'),
#  (9, 'North of the Wall', 'Nightswatch March South')]

# %%
# %sql select * from HW4GoT.scenes limit 10
# Out:
#  * mysql+pymysql://root:***@localhost/HW4GoT
# 10 rows affected.
# [(0, 1, 1, 1, '0:00:40', '0:01:45', 'The Wall', 'Castle Black', None, None, None, None),
#  (1, 1, 1, 2, '0:01:45', '0:03:24', 'North of the Wall', 'The Haunted Forest', None, None, None, None),
#  (2, 1, 1, 3, '0:03:24', '0:03:31', 'North of the Wall', 'The Haunted Forest', None, None, None, None),
#  (3, 1, 1, 4, '0:03:31', '0:03:38', 'North of the Wall', 'The Haunted Forest', None, None, None, None),
#  (4, 1, 1, 5, '0:03:38', '0:03:44', 'North of the Wall', 'The Haunted Forest', None, None, None, None),
#  (5, 1, 1, 6, '0:03:44', '0:05:36', 'North of the Wall', 'The Haunted Forest', None, None, None, None),
#  (6, 1, 1, 7, '0:05:36', '0:05:41', 'North of the Wall', 'The Haunted Forest', None, None, None, None),
#  (7, 1, 1, 8, '0:05:41', '0:05:48', 'North of the Wall', 'The Haunted Forest', None, None, None, None),
# ...

# %%
# %sql select * from HW4GoT.scenes_characters limit 10
# Out:
#  * mysql+pymysql://root:***@localhost/HW4GoT
# 10 rows affected.
# [(0, 1, 1, 1, 'Gared'),
#  (1, 1, 1, 1, 'Waymar Royce'),
#  (2, 1, 1, 1, 'Will'),
#  (3, 1, 1, 2, 'Gared'),
#  (4, 1, 1, 2, 'Waymar Royce'),
#  (5, 1, 1, 2, 'Will'),
#  (6, 1, 1, 3, 'Will'),
#  (7, 1, 1, 3, 'Wight Wildling Girl'),
#  (8, 1, 1, 4, 'Will'),
#  (9, 1, 1, 6, 'Gared')]

# %% [markdown]
# IMDB

# %%
# %sql mysql+pymysql://root:Zhr990512@@localhost/HW4IMDB

# %%
# %sql show tables from HW4IMDB
# Out:
#    mysql+pymysql://root:***@localhost/HW4GoT
#  * mysql+pymysql://root:***@localhost/HW4IMDB
# 1 rows affected.
# [('title_ratings',)]

# %%
# %sql select * from HW4IMDB.title_ratings limit 10
# Out:
#    mysql+pymysql://root:***@localhost/HW4GoT
#  * mysql+pymysql://root:***@localhost/HW4IMDB
# 10 rows affected.
# [('tt0000001', 5.6, 1664),
#  ('tt0000002', 6.1, 205),
#  ('tt0000003', 6.5, 1381),
#  ('tt0000004', 6.2, 123),
#  ('tt0000005', 6.2, 2167),
#  ('tt0000006', 5.3, 117),
#  ('tt0000007', 5.4, 663),
#  ('tt0000008', 5.4, 1832),
#  ('tt0000009', 6.0, 154),
#  ('tt0000010', 6.9, 6099)]
